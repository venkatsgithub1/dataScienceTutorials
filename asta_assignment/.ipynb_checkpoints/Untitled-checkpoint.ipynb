# %%
import pandas as pd

# %%
df = pd.read_csv('12)ToyotaCorolla.csv')
df.head(20)
# Out:
#     Price  Age     KM FuelType   HP  MetColor  Automatic    CC  Doors  Weight
# 0   13500   23  46986   Diesel   90         1          0  2000      3    1165
# 1   13750   23  72937   Diesel   90         1          0  2000      3    1165
# 2   13950   24  41711   Diesel   90         1          0  2000      3    1165
# 3   14950   26  48000   Diesel   90         0          0  2000      3    1165
# 4   13750   30  38500   Diesel   90         0          0  2000      3    1170
# 5   12950   32  61000   Diesel   90         0          0  2000      3    1170
# 6   16900   27  94612   Diesel   90         1          0  2000      3    1245
# 7   18600   30  75889   Diesel   90         1          0  2000      3    1245
# 8   21500   27  19700   Petrol  192         0          0  1800      3    1185
# 9   12950   23  71138   Diesel   69         0          0  1900      3    1105
# 10  20950   25  31461   Petrol  192         0          0  1800      3    1185
# ...

# %%
df.columns
# Out:
# Index(['Price', 'Age', 'KM', 'FuelType', 'HP', 'MetColor', 'Automatic', 'CC',
#        'Doors', 'Weight'],
#       dtype='object')

# %% [markdown]
# # Predict price using useful independent variables.

# %%
import seaborn as sns

# %%
sns.pairplot(df, y_vars='Price', x_vars=['Age', 'KM', 'FuelType', 'HP', 'MetColor', 'Automatic', 'CC','Doors', 'Weight'])

# %% [markdown]
# From above, Age and KM can be used.
